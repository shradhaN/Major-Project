# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("firewall_reduced_ascii.csv")

# %%
df
# Out:
#         action  protocol  src-ip  dst-ip  src-port  dst-port  size  path
# 0          383       233     685     558       259       257    48   515
# 1          383       233     704     558       255       257    48   515
# 2          383       233     703     558       205       257    48   515
# 3          383       233     745     558       262       257    48   515
# 4          383       231     704     558       271       257    48   515
# 5          383       233     563     558       265       257    48   515
# 6          383       233     691     558       248       257    48   515
# 7          383       233     610     558       263       257    48   515
# 8          383       231     558     606       260       104    48   298
# 9          383       233     659     558       262       257    48   515
# 10         383       231     713     558       264       257    48   515
# 11         383       233     558     711       257       254    48   298
# ...

# %%
df1 = df.head(1000)

# %%
df1.to_csv("only1000.csv",index=False)

# %%
df2 = pd.read_csv("firewall_reduced.csv")

# %%
df2
# Out:
#        action protocol           src-ip           dst-ip src-port dst-port  \
# 0       ALLOW      UDP   213.230.102.14      192.168.1.8    48043    42065
# 1       ALLOW      UDP   142.129.208.72      192.168.1.8    14217    42065
# 2       ALLOW      UDP   34.209.224.146      192.168.1.8     8104    42065
# 3       ALLOW      UDP  124.114.154.170      192.168.1.8    15376    42065
# 4       ALLOW      TCP   213.172.152.86      192.168.1.8    59089    42065
# 5       ALLOW      UDP      95.47.45.43      192.168.1.8    64393    42065
# 6       ALLOW      UDP   210.222.91.114      192.168.1.8    52100    42065
# 7       ALLOW      UDP     148.251.46.9      192.168.1.8    45464    42065
# 8       ALLOW      TCP      192.168.1.8     37.187.23.23    57503       80
# 9       ALLOW      UDP    37.49.126.126      192.168.1.8    46129    42065
# 10      ALLOW      TCP   115.127.96.177      192.168.1.8    33657    42065
# ...

# %%
df2['src-ip'].to_csv("src-ip.csv",index=False)

# %%
df2[]
# Out:
#   File "<ipython-input-12-c5bea6320af9>", line 1
#     df2[,:2]
#         ^
# SyntaxError: invalid syntax

# %%
df2.dtypes
# Out:
# action      object
# protocol    object
# src-ip      object
# dst-ip      object
# src-port    object
# dst-port    object
# size        object
# path        object
# dtype: object

# %%
df2
# Out:
#        action protocol           src-ip           dst-ip src-port dst-port  \
# 0       ALLOW      UDP   213.230.102.14      192.168.1.8    48043    42065
# 1       ALLOW      UDP   142.129.208.72      192.168.1.8    14217    42065
# 2       ALLOW      UDP   34.209.224.146      192.168.1.8     8104    42065
# 3       ALLOW      UDP  124.114.154.170      192.168.1.8    15376    42065
# 4       ALLOW      TCP   213.172.152.86      192.168.1.8    59089    42065
# 5       ALLOW      UDP      95.47.45.43      192.168.1.8    64393    42065
# 6       ALLOW      UDP   210.222.91.114      192.168.1.8    52100    42065
# 7       ALLOW      UDP     148.251.46.9      192.168.1.8    45464    42065
# 8       ALLOW      TCP      192.168.1.8     37.187.23.23    57503       80
# 9       ALLOW      UDP    37.49.126.126      192.168.1.8    46129    42065
# 10      ALLOW      TCP   115.127.96.177      192.168.1.8    33657    42065
# ...

# %%
df2['src-ip']
# Out:
# 0          213.230.102.14
# 1          142.129.208.72
# 2          34.209.224.146
# 3         124.114.154.170
# 4          213.172.152.86
# 5             95.47.45.43
# 6          210.222.91.114
# 7            148.251.46.9
# 8             192.168.1.8
# 9           37.49.126.126
# 10         115.127.96.177
# 11            192.168.1.8
# 12         45.241.223.111
# 13            192.168.1.8
# 14          103.199.161.6
# 15          41.212.58.187
# 16            192.168.1.2
# 17            192.168.1.8
# 18           213.99.35.18
# 19          59.93.158.119
# 20        110.171.127.250
# 21            192.168.1.2
# 22            192.168.1.8
# 23            192.168.1.2
# 24            192.168.1.8
# 25            192.168.1.8
# 26            192.168.1.8
# 27          121.16.63.152
# 28           89.64.10.207
# 29            80.3.234.79
#                ...
# 348787        192.168.1.8
# 348788        192.168.1.8
# 348789        192.168.1.8
# 348790        192.168.1.8
# ...

# %%
df2.loc[df2['src-ip'] == '89.248.168.171']
# Out:
# Empty DataFrame
# Columns: [action, protocol, src-ip, dst-ip, src-port, dst-port, size, path]
# Index: []

# %%
df2.loc['dst-ip'=="89.248.168.171"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-c38776b05264> in <module>()
# ----> 1 df2.loc[dst-ip=="89.248.168.171"]
#
# NameError: name 'dst' is not defined

# %%
df2.loc[712]
# Out:
# action              ALLOW
# protocol              UDP
# src-ip        192.168.1.8
# dst-ip      106.51.154.26
# src-port            56664
# dst-port            31440
# size                    0
# path                 SEND
# Name: 712, dtype: object

# %%
df2.loc[df2['action']=="ALLOW"]
# Out:
#        action protocol           src-ip           dst-ip src-port dst-port  \
# 0       ALLOW      UDP   213.230.102.14      192.168.1.8    48043    42065
# 1       ALLOW      UDP   142.129.208.72      192.168.1.8    14217    42065
# 2       ALLOW      UDP   34.209.224.146      192.168.1.8     8104    42065
# 3       ALLOW      UDP  124.114.154.170      192.168.1.8    15376    42065
# 4       ALLOW      TCP   213.172.152.86      192.168.1.8    59089    42065
# 5       ALLOW      UDP      95.47.45.43      192.168.1.8    64393    42065
# 6       ALLOW      UDP   210.222.91.114      192.168.1.8    52100    42065
# 7       ALLOW      UDP     148.251.46.9      192.168.1.8    45464    42065
# 8       ALLOW      TCP      192.168.1.8     37.187.23.23    57503       80
# 9       ALLOW      UDP    37.49.126.126      192.168.1.8    46129    42065
# 10      ALLOW      TCP   115.127.96.177      192.168.1.8    33657    42065
# ...

# %%
print(df2['src-ip'] == '89.248.168.171')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 348787    False
# 348788    False
# 348789    False
# 348790    False
# 348791    False
# 348792    False
# 348793    False
# 348794    False
# 348795    False
# 348796    False
# 348797    False
# 348798    False
# 348799    False
# 348800    False
# 348801    False
# 348802    False
# 348803    False
# 348804    False
# 348805    False
# 348806    False
# 348807    False
# 348808    False
# 348809    False
# 348810    False
# ...

# %%
df = pd.read_csv("src-ip.csv")

# %%
df.drop_duplicates(keep = "first")
# Out:
#                  src-ip
# 0        213.230.102.14
# 1        142.129.208.72
# 2        34.209.224.146
# 3       124.114.154.170
# 4        213.172.152.86
# 5           95.47.45.43
# 6        210.222.91.114
# 7          148.251.46.9
# 8           192.168.1.8
# 9         37.49.126.126
# 10       115.127.96.177
# 12       45.241.223.111
# 14        103.199.161.6
# 15        41.212.58.187
# 16          192.168.1.2
# 18         213.99.35.18
# 19        59.93.158.119
# 20      110.171.127.250
# 27        121.16.63.152
# 28         89.64.10.207
# 29          80.3.234.79
# 30        41.90.186.113
# 31         37.142.6.147
# 32         103.38.12.30
# 33       114.34.243.184
# 34       117.198.193.76
# 35      112.119.239.222
# 36         5.189.185.57
# 38        117.81.51.126
# 41         104.207.83.2
# ...                 ...
# 342316     47.89.243.33
# 342347   220.174.209.53
# 342350  115.204.212.170
# 342439  193.179.213.242
# 342455     39.86.129.22
# 342471    184.18.46.215
# ...

# %%
df2 = pd.read_csv("firewall_reduced.csv")

# %%
df_dst = df2['dst-ip'].drop_duplicates(keep = 'first')

# %%
df_dst.to_csv("dst-ip.csv", index = False)

# %%
df_dst = pd.read_csv("dst-ip.csv")

# %%
df_dst
# Out:
#                                      dst-ip
# 0                               192.168.1.8
# 1                              37.187.23.23
# 2                            108.61.198.227
# 3                               224.0.0.251
# 4                             157.49.42.252
# 5                             175.184.3.118
# 6                              35.190.66.65
# 7                             197.245.31.40
# 8                              18.195.47.86
# 9                            158.174.16.120
# 10                           34.245.157.173
# 11                           108.41.198.183
# 12                              86.97.47.83
# 13                           103.247.48.107
# 14                            27.147.226.57
# 15                           122.52.134.144
# 16     2001:0:4137:9e76:1419:22a7:ce0b:c7a7
# 17                            102.157.216.4
# 18                              93.86.40.20
# 19                              192.168.1.1
# ...

# %% [markdown]
# # Scraping IBM'S X-FORCE to label the IP ADDRESSES

# %% [markdown]
# https://exchange.xforce.ibmcloud.com

# %%
#scrape garne url : https://exchange.xforce.ibmcloud.com/ip/<ip-address>
