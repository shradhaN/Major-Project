# %%
from selenium import webdriver
import pandas as pd
import numpy as np
import csv

# %%
driver = webdriver.Firefox()
driver.set_page_load_timeout(50)

# loop over dataframe, add 2 new columns for each row: 1. risk factor , category
driver.get('https://exchange.xforce.ibmcloud.com/')
#driver.maximize_window()
driver.implicitly_wait(100)
driver.find_element_by_id("termsCheckbox").click()
driver.find_element_by_class_name("guestlogin").click()


with open("src-ip-50.csv") as f:
    reader = csv.reader(f)
    
    for row in reader:
        
        driver.get('https://exchange.xforce.ibmcloud.com/ip/'+ row[0] +'')
        #driver.maximize_window()
        driver.implicitly_wait(100)
       # driver.find_element_by_id("termsCheckbox").click()
       # driver.find_element_by_class_name("guestlogin").click()
        #driver.implicitly_wait(100)
        #driver.find_element_by_id("top_search").send_keys('41.250.128.68')
        #driver.implicitly_wait(100)
        #driver.find_element_by_id('btnClose').click()
        driver.implicitly_wait(10)
        #driver.find_element_by_id("submitTopSearch").click()
        with open('src-ip-categorized-revised.csv', 'a')as out_file:
            writer = csv.writer(out_file)
            writer.writerow(('src-ip','risk-factor','categories'))
            risk_factor = driver.find_element_by_class_name("scorebackgroundfilter.numtitle").text
            #print(risk_factor)
            category = driver.find_element_by_id("categories").text
            #print(category)
            value = [row[0],risk_factor,category]
            
            writer.writerow(value)
      
        driver.implicitly_wait(10)

# store the categories and risk
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-809b0e1e5b7a> in <module>()
#      29             writer = csv.writer(out_file)
#      30             writer.writerow(('src-ip','risk-factor','categories'))
# ---> 31             risk_factor = driver.find_element_by_class_name("scorebackgroundfilter.numtitle").text
#      32             #print(risk_factor)
#      33             category = driver.find_element_by_id("categories").text
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in find_element_by_class_name(self, name)
#     555             element = driver.find_element_by_class_name('foo')
#     556         """
# --> 557         return self.find_element(by=By.CLASS_NAME, value=name)
#     558
#     559     def find_elements_by_class_name(self, name):
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in find_element(self, by, value)
#     955         return self.execute(Command.FIND_ELEMENT, {
#     956             'using': by,
# --> 957             'value': value})['value']
#     958
#     959     def find_elements(self, by=By.ID, value=None):
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/errorhandler.pyc in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: Failed to decode response from marionette

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("src-ip.csv").drop_duplicates(keep = "first")

# %%
df.to_csv("src-ip-dropped.csv", index= False)

# %%
df = pd.read_csv("src-ip-dropped.csv")

# %%
df[1740:1800]
# Out:
#                  213.230.102.14
# 1740              178.68.228.16
# 1741                113.251.6.1
# 1742                59.42.123.1
# 1743              178.78.33.127
# 1744             183.171.81.189
# 1745              61.158.149.70
# 1746              132.251.0.129
# 1747              218.209.211.9
# 1748             89.160.233.103
# 1749              111.101.63.81
# 1750             117.11.121.228
# 1751             187.179.76.232
# 1752              190.121.80.97
# 1753             123.231.115.20
# 1754             71.167.150.192
# 1755             122.174.251.48
# 1756             110.54.226.151
# 1757             91.243.110.159
# 1758              24.192.65.163
# 1759             124.60.175.146
# 1760                91.77.57.26
# 1761              113.180.144.8
# 1762               27.114.29.80
# 1763               1.186.182.77
# 1764            118.175.218.174
# 1765            116.253.140.123
# 1766              84.246.166.14
# 1767               79.156.190.9
# 1768               61.3.194.150
# 1769                176.92.29.3
# 1770                60.255.32.7
# 1771             217.170.164.44
# 1772            118.212.156.174
# 1773               73.61.104.52
# 1774            175.142.147.232
# 1775             72.252.198.129
# 1776              87.191.151.76
# 1777             220.175.84.209
# 1778              95.42.126.252
# 1779             194.183.77.196
# 1780              77.230.71.170
# 1781              123.231.16.95
# 1782               223.16.84.31
# 1783               5.145.204.28
# 1784             79.124.120.145
# 1785                 27.34.20.3
# 1786               39.42.34.158
# 1787                2.89.237.86
# 1788              68.108.106.65
# 1789            164.132.140.157
# 1790              183.142.53.32
# 1791             105.27.200.194
# 1792             60.180.163.124
# 1793              112.51.20.205
# 1794             49.142.178.216
# 1795               88.17.39.233
# 1796            179.181.143.240
# 1797  fe80::d287:e2ff:fe80:d488
# 1798              58.230.17.221
# 1799              197.156.77.75

# %%
df[1800:1810].to_csv('src-ip-50.csv', index = False)

# %% [markdown]
# df[1]

# %%
import csv

with open("src-ip-50.csv") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row[0])
# Out:
# 142.129.208.72
# 34.209.224.146
# 124.114.154.170
# 213.172.152.86
# 95.47.45.43
# 210.222.91.114
# 148.251.46.9
# 192.168.1.8
# 37.49.126.126
# 115.127.96.177
# 45.241.223.111
# 103.199.161.6
# 41.212.58.187
# 192.168.1.2
# 213.99.35.18
# 59.93.158.119
# 110.171.127.250
# 121.16.63.152
# 89.64.10.207
# 80.3.234.79
# 41.90.186.113
# 37.142.6.147
# 103.38.12.30
# 114.34.243.184
# 117.198.193.76
# 112.119.239.222
# 5.189.185.57
# 117.81.51.126
# 104.207.83.2
# 115.193.11.152
# 83.44.154.208
# 175.136.35.54
# 59.91.17.238
# 82.178.214.156
# 103.226.5.56
# 125.111.198.36
# 126.94.235.75
# 50.65.96.193
# 59.56.46.107
# 2001:0:9d38:6abd:3411:260b:7457:2e38
# 41.250.128.68
# 180.191.92.23
# 167.249.144.8
# 185.21.216.171
# 94.242.238.66
# 102.157.216.4
# 112.172.207.135
# 179.159.56.49
# 60.246.176.14

# %%
import os,csv,json

from bs4 import BeautifulSoup as soup
import requests

# %%
my_url =

# %%
with open("src-ip-50.csv") as f:
    reader = csv.reader(f)
    i = 0
    for row in reader:
        url = driver.get('https://exchange.xforce.ibmcloud.com/ip/'+ row[0] +'')
# Out:
# ['142.129.208.72']
# ['34.209.224.146']
# ['124.114.154.170']
# ['213.172.152.86']
# ['95.47.45.43']
# ['210.222.91.114']
# ['148.251.46.9']
# ['192.168.1.8']
# ['37.49.126.126']
# ['115.127.96.177']
# ['45.241.223.111']
# ['103.199.161.6']
# ['41.212.58.187']
# ['192.168.1.2']
# ['213.99.35.18']
# ['59.93.158.119']
# ['110.171.127.250']
# ['121.16.63.152']
# ['89.64.10.207']
# ['80.3.234.79']
# ['41.90.186.113']
# ['37.142.6.147']
# ['103.38.12.30']
# ['114.34.243.184']
# ['117.198.193.76']
# ['112.119.239.222']
# ['5.189.185.57']
# ['117.81.51.126']
# ['104.207.83.2']
# ['115.193.11.152']
# ['83.44.154.208']
# ['175.136.35.54']
# ['59.91.17.238']
# ['82.178.214.156']
# ['103.226.5.56']
# ['125.111.198.36']
# ['126.94.235.75']
# ['50.65.96.193']
# ['59.56.46.107']
# ['2001:0:9d38:6abd:3411:260b:7457:2e38']
# ['41.250.128.68']
# ['180.191.92.23']
# ['167.249.144.8']
# ['185.21.216.171']
# ['94.242.238.66']
# ['102.157.216.4']
# ['112.172.207.135']
# ['179.159.56.49']
# ['60.246.176.14']

# %%
driver = webdriver.Firefox()
driver.set_page_load_timeout(75)

# loop over dataframe, add 2 new columns for each row: 1. risk factor , category
driver.get('https://exchange.xforce.ibmcloud.com/')
#driver.maximize_window()
driver.implicitly_wait(100)
driver.find_element_by_id("termsCheckbox").click()
driver.find_element_by_class_name("guestlogin").click()

with open('src-ip-categorized-revised.csv', 'a')as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('src-ip','risk-factor','categories'))
        with open("src-ip-50.csv") as f:
            reader = csv.reader(f)    
            for row in reader:
                driver.get('https://exchange.xforce.ibmcloud.com/ip/'+ row[0] +'')
                #driver.maximize_window()
                driver.implicitly_wait(100)
                risk_factor = driver.find_element_by_class_name("scorebackgroundfilter.numtitle").text
                #print(risk_factor)
                category = driver.find_element_by_id("categories").text
                #print(category)
                value = [row[0],risk_factor,category]
                writer.writerow(value)
                driver.implicitly_wait(10)              
        
            driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-9-0ce672bf0fde> in <module>()
#      18                 #driver.maximize_window()
#      19                 driver.implicitly_wait(100)
# ---> 20                 risk_factor = driver.find_element_by_class_name("scorebackgroundfilter.numtitle").text
#      21                 #print(risk_factor)
#      22                 category = driver.find_element_by_id("categories").text
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in find_element_by_class_name(self, name)
#     555             element = driver.find_element_by_class_name('foo')
#     556         """
# --> 557         return self.find_element(by=By.CLASS_NAME, value=name)
#     558
#     559     def find_elements_by_class_name(self, name):
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in find_element(self, by, value)
#     955         return self.execute(Command.FIND_ELEMENT, {
#     956             'using': by,
# --> 957             'value': value})['value']
#     958
#     959     def find_elements(self, by=By.ID, value=None):
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# /home/shradha/virtualenvironment/ML/local/lib/python2.7/site-packages/selenium/webdriver/remote/errorhandler.pyc in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: Failed to find value field

# %%
250
